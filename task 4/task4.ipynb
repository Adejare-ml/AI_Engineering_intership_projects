# %%
import pandas as  pd 
import numpy  as np
# %matplotlib inline
import matplotlib.pyplot as  plt 


df  =pd.read_csv(r"C:\Users\adelu\OneDrive\Documents\AI_Engineering_intership_projects\task 4\car-sales-extended-missing-data.csv" , encoding ="latin-1")
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
# Handling  mising values 
df.isna().sum()
df = df.dropna()

# %%
# checking  to see  of  all  missing  values are dropped
df.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
#noramlize  columns  name
